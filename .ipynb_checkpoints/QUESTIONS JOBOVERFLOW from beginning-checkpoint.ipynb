# %% [markdown]
# ![image.png](attachment:a31e79a5-c903-4e9f-ac79-85117a4c4f78.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# using state=pair<int,int>;
# const int INF=LONG_MAX;
#
#
# vector<vector<int>>adj;
# int x1,x2,x3,a,b;
#
# vector<int>func(int s,int cost){
#     vector<int>d(a+1,INF);
#     d[s]=0;
#
#
#     priority_queue<state,vector<state>,greater<state>>pq;
#     pq.push({0,s});
#
#
#     while(!pq.empty()){
#         int curd=pq.top().first;
#         int u=pq.top().second;
#         pq.pop();
#         if(curd>d[u])continue;
#
#
#         for(auto it:adj[u]){
#             int newd=curd+cost;
#             if(newd<d[it]){
#                 d[it]=newd;
#                 pq.push({newd,it});
#             }
#         }
#     }
#     return d;
# }
#
#
#
# void solve(){
#
#     cin>>x1>>x2>>x3>>a>>b;
#     adj.clear();
#     adj.resize(a+1);
#     for(int i=0;i<b;i++){
#         int u,v;
#         cin>>u>>v;
#         adj[u].push_back(v);
#         adj[v].push_back(u);
#     }
#
#     vector<int>d1=func(1,x1);// Shortest distance from node 1 with cost x1
#     vector<int>d2=func(2,x2);// Shortest distance from node 2 with cost x2
#     vector<int>d3=func(a,x3);// Shortest distance from node 'a' with cost x3
#
#
#     int res=INF;
#     for(int i=1;i<=a;i++){
#         res=min(res,d1[i]+d2[i]+d3[i]);
#     }
#     cout<<res<<endl;
#
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }
#
# //https://www.thejoboverflow.com/problem/1/

# %% [markdown]
# ![image.png](attachment:b7c1169f-d527-4429-aab8-24296b58413b.png)
# ![image.png](attachment:d201b5af-a4de-4529-b42b-d4d5110d35c2.png)

# %% [markdown]
# ```cpp
#
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
# int maxSumSubarray(vector<int>&arr){
# 	int maxi=arr[0];
# 	int maxSum=arr[0];
# 	for(int i=1;i<arr.size();i++){
# 		maxi=max(arr[i],maxi+arr[i]);
# 		maxSum=max(maxSum,maxi);
# 	}
# 	return maxSum;
# }
#
# int minSumSubarray(vector<int>&arr){
# 	int mini=arr[0];
# 	int minSum=arr[0];
# 	for(int i=1;i<arr.size();i++){
# 		mini=min(arr[i],mini+arr[i]);
# 		minSum=min(minSum,mini);
# 	}
# 	return minSum;
# }
#
#
# int maxSubarray(vector<int>&arr){
# 	int maxi=maxSumSubarray(arr);
# 	int ans=accumulate(arr.begin(),arr.end(),0);
# 	int mini=minSumSubarray(arr);
#
# 	if(ans==mini){
# 		return maxi;
# 	}
# 	return max(maxi,ans-mini);
# }
#
#
#
# void solve(){
#     int n;
#     cin>>n;
#     vector<int>arr;
#     for(int i=0;i<n;i++){
#     	int x;
#     	cin>>x;
#     	arr.push_back(x);
#     }
#     cout<<maxSubarray(arr)<<endl;
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:17c4b468-b7d9-4a6f-8636-311804fd55b8.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#
#   int n,m;
#   cin>>n>>m;
#   pair<int,int>alice;
#   vector<vector<char>>arr(n,vector<char>(m));
#   vector<vector<int>>monsters(n,vector<int>(m,INT_MAX));
#   queue<vector<int>>q;
#   for(int i=0;i<n;i++){
#     for(int j=0;j<m;j++){
#       cin>>arr[i][j];
#
#
#       if(arr[i][j]=='A'){
#         alice.first=i;
#         alice.second=j;
#
#       }else if(arr[i][j]=='M'){
#         monsters[i][j]=0;
#         q.push({i,j,0});
#       }
#     }
#   }
#
#
#   vector<vector<int>>moves={{1,0},{0,1},{-1,0},{0,-1}};
#
#
#   while(!q.empty()){
#     auto t=q.front();
#     q.pop();
#     int row=t[0];
#     int col=t[1];
#     int time=t[2];
#
#
#     for(auto move:moves){
#       int nr=row+move[0];
#       int nc=col+move[1];
#       if(nr>=0 && nr<n  && nc>=0 && nc<m && monsters[nr][nc]==INT_MAX && arr[nr][nc]!='#'){
#         monsters[nr][nc]=time+1;
#         q.push({nr,nc,time+1});
#       }
#     }
#   }
#
#
#   q.push({alice.first,alice.second,0});
#   bool possible=false;
#
#   while(!q.empty()){
#     auto t=q.front();
#     q.pop();
#     int row=t[0];
#     int col=t[1];
#     int time=t[2];
#
#
#     if((row==n-1) || (col==m-1) || (row==0) || (col==0)){
#       possible=true;
#       break;
#     }
#
#
#
#     for(auto move:moves){
#       int nr=row+move[0];
#       int nc=col+move[1];
#       if(nr>=0 && nr<n  && nc>=0 && nc<m && monsters[nr][nc]>time+1 && arr[nr][nc]!='#'){
#         monsters[nr][nc]=time+1;
#         q.push({nr,nc,time+1});
#       }
#     }
#
#
#
#
#
#   }
#
#
#   if(possible)cout<<"YES"<<endl;
#   else cout<<"NO"<<endl;
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:49526c16-8eb3-4224-b3b3-63b99568fd14.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#   int n,k;
#   cin>>n>>k;
#   string sp,s;
#   cin>>sp>>s;
#
#   int x=0;
#   map<char,int>mp;
#   for(auto ch:sp){
#     mp[ch]=x;
#     x++;
#   }
#
#   stack<char>st;
#   for(int i=0;i<s.size();i++){
#     while(!st.empty() && mp[st.top()]>mp[s[i]]  && st.size()-1+n-i>=k){
#       st.pop();
#     }
#
#
#     if(st.size()<k){
#       st.push(s[i]);
#     }
#   }
#
#   string ans="";
#   while(!st.empty()){
#     ans.push_back(st.top());
#     st.pop();
#   }
#   reverse(ans.begin(),ans.end());
#   cout<<ans<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:7ce0db07-5dd4-4794-a073-f3d0f2374ec8.png)

# %% [markdown]
# ```cpp
#
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
# const int mod=1e9+7;
#
# int f(int ind,int p,int prev,int n,int m,vector<int>&a,vector<int>&b,vector<vector<int>>&dp){
#   if(p==m){
#     return 1;
#   }
#   if(ind==n){
#     return 0;
#   }
#
#   if(dp[ind][p]!=-1){
#     return dp[ind][p];
#   }
#   int ans=0;
#
#   for(int i=ind;i<n;i++){
#     if(a[i]+b[p]>=prev){
#       ans+=f(i+1,p+1,a[i]+b[p],n,m,a,b,dp);
#     }
#     ans=ans%mod;
#   }
#
#   return dp[ind][p]=ans;
# }
#
#
#
# void solve(){
#     int n,m;
#     cin>>n>>m;
#     vector<int>arr1(n),arr2(m);
#     for(int i=0;i<n;i++){
#       cin>>arr1[i];
#     }
#     for(int i=0;i<m;i++){
#       cin>>arr2[i];
#     }
#
#     vector<vector<int>>dp(n,vector<int>(m,-1));
#
#     cout<<f(0,0,0,n,m,arr1,arr2,dp)<<endl;
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:fe660609-3c05-4f16-8771-e14c9587371a.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
# int f(int n,int k){
#   if(n==1){
#     return 0;
#   }
#
#   return (f(n-1,k)+k)%n;
# }
#
#
# void solve(){
#
#   int n,k;
#   cin>>n>>k;
#   cout<<f(n,k)+1<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:220935c4-f23a-49f3-a537-173cfa5cef8f.png)
# ![image.png](attachment:3b4dfec7-7511-4f99-9d21-4fa9afef36ef.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#   int n,m;
#   cin>>n>>m;
#   map<int,vector<int>>mp;
#   for(int i=0;i<n;i++){
#     for(int j=0;j<m;j++){
#       int x;
#       cin>>x;
#       mp[i+j].push_back(x);
#     }
#   }
#
#   for(auto &it:mp){
#     if(!(it.first&1)){
#       reverse(it.second.begin(),it.second.end());
#     }
#     for(auto &i:it.second){
#       cout<<i<<" ";
#     }
#   }
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:d92c97b7-908f-4d2b-9371-0f486081fe35.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#   string s;
#   getline(cin,s);
#   char ch;
#   cin>>ch;
#
#   int f=-1,l=-1;
#   for(int i=0;i<s.size();i++){
#     if(s[i]==ch){
#       if(f==-1){
#         f=i;
#       }
#       l=i;
#     }
#   }
#
#
#   if(l==-1 || l==f){
#     cout<<-1<<endl;
#     return;
#   }
#
#
#
#
#   unordered_map<char,int>vis;
#   for(int i=f+1;i<l;i++){
#     if(s[i]!=' ' and s[i]!=ch){
#       vis[s[i]]++;
#     }
#
#   }
#   cout<<vis.size()<<endl;
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:117b1a0d-8e7b-41d8-9140-ad1f15481a7c.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#     int n;
#     cin>>n;
#     vector<int>arr(n);
#     for(int i=0;i<n;i++){
#       cin>>arr[i];
#     }
#     vector<int>pref(n),suff(n);
#     pref[0]=arr[0];
#     for(int i=1;i<n;i++){
#       pref[i]=max(pref[i-1],arr[i]);
#     }
#     suff[n-1]=arr[n-1];
#     for(int i=n-2;i>=0;i--){
#       suff[i]=max(suff[i+1],arr[i]);
#     }
#
#     int ans=0;
#     for(int i=0;i<n;i++){
#       ans+=min(pref[i],suff[i])-arr[i];
#     }
#     cout<<ans<<endl;
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:562f283b-72d0-48dc-abee-efd2d8ea8f7c.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
# const int mod=1e9+7;
#
# int f(int r,int c,int n,int m,int k,vector<vector<vector<int>>>&dp){
#   if(r<0 || r>=n || c<0 || c>=m){
#     return 1;
#   }
#
#   if(k==0){
#     return 0;
#   }
#
#   if(dp[r][c][k]!=-1){
#     return dp[r][c][k];
#   }
#
#
#   vector<vector<int>>moves={{0,1},{0,-1},{1,0},{-1,0}};
#   int ans=0;
#   for(auto &move:moves){
#     ans=(ans+f(r+move[0],c+move[1],n,m,k-1,dp))%mod;
#   }
#
#   return dp[r][c][k]=ans;
# }
#
#
#
# void solve(){
#
#
#   int n,m,k,r,c;
#   cin>>n>>m>>k>>r>>c;
#
#
#   vector<vector<vector<int>>>dp(n+1,vector<vector<int>>(m+1,vector<int>(k+1,-1)));
#   cout<<f(r,c,n,m,k,dp)<<endl;
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:15285e80-09c9-4da0-8dc9-2c6600b4effd.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
# bool check(vector<int>&f1,vector<int>&f2){
#   int c=0;
#   for(int i=0;i<=1000;i++){
#     if(f1[i]!=f2[i]){
#       c++;
#     }
#   }
#   if(c==1)return 1;
#   return 0;
# }
#
#
#
# void solve(){
#
#   int n,m;
#   cin>>n>>m;
#
#
#   if(m==1){
#     cout<<-1<<endl;
#     return;
#   }
#
#
#   vector<int>a(n);
#   vector<int>b(m);
#   for(int i=0;i<n;i++){
#     cin>>a[i];
#   }
#   for(int i=0;i<m;i++){
#     cin>>b[i];
#   }
#
#   vector<int>fa(1001);
#   vector<int>fb(1001);
#   for(int i=0;i<m;i++){
#     fb[b[i]]++;
#   }
#   for(int i=0;i<m-2;i++){
#     fa[a[i]]++;
#   }
#
#   bool flag=false;
#   for(int i=m-2;i<n;i++){
#     fa[a[i]]++;
#     if(check(fa,fb)){
#       flag=1;
#       cout<<(i-m+2+1)<<" ";
#     }
#     fa[a[i-m+2]]--;
#   }
#
#   if(!flag)cout<<-1;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:0eab6268-ea9a-44cc-a5c9-876179584721.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
# bool f(int num){
#   if(num>=0){
#     int root=sqrt(num);
#     return root*root==num;
#   }
#   return 0;
# }
#
# void solve(){
#
#   int n;cin>>n;
#   vector<int>arr;
#   for(int i=0;i<n;i++){
#     int x;
#     cin>>x;
#     arr.push_back(x);
#   }
#
#   int result=0;
#   for(int i=0;i<n;i++){
#     if(f(arr[i])){
#       result++;
#     }
#   }
#   cout<<result<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:f666d7a3-ded7-4601-aa18-7628db20b5df.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#
#     string s;
#     cin>>s;
#     int n;
#     cin>>n;
#     string ans="";
#     for(int i=0;i<s.size();i++){
#         if(isupper(s[i])){
#             if(i==0){
#                 ans.push_back(tolower(s[i]));
#             }else{
#                 ans.push_back('_');
#                 ans.push_back(tolower(s[i]));
#
#             }
#         }else{
#             ans.push_back(s[i]);
#         }
#     }
#     cout<<ans<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:277c6692-c939-468f-8c5c-0314060882c6.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#   int n,k;
#   cin>>n>>k;
#   vector<int>arr(n);
#   priority_queue<int,vector<int>,greater<int>>pq;
#   for(int i=0;i<n;i++){
#     cin>>arr[i];
#     pq.push(arr[i]);
#   }
#   set<int>vis;
#
#
#   while(!pq.empty()){
#     int x=pq.top();
#     pq.pop();
#
#
#     if(vis.find(x)!=vis.end())continue;
#
#
#     k--;
#     if(k==0){
#       cout<<x<<endl;
#       break;
#     }
#
#     for(int i=0;i<n;i++){
#       pq.push(x*arr[i]);
#     }
#
#   }
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:a80ae467-b5ce-4ac5-a645-465d07d751c0.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
# void extended_gcd(int a,int b,vector<int>&v){
#     if(b==0){
#         v[2]=a;
#         v[0]=1;
#         v[1]=0;
#         return;
#     }
#     extended_gcd(b,a%b,v);
#     int x1=v[0],y1=v[1];
#     v[0]=y1;
#     v[1]=x1-(a/b)*y1;
#
# }
#
#
#
# void solve(){
#
#
#     int a,r,n;
#     cin>>a>>r>>n;
#
#     vector<int>v(3);
#     extended_gcd(a,n,v);
#
#     if(r%v[2]){
#         cout<<-1<<endl;
#         return;
#     }
#
#
#     int x=(r/v[2])*v[0];
#
#     x=(x%n+n)%n;
#
#
#
#     int ans=x;
#
#     for(int k=0;k<v[2];k++){
#         x=(x+n/v[2])%n;
#         ans=min(ans,x);
#     }
#
#     cout<<ans<<endl;
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:39c26de5-b1bf-4a68-8022-6cf39ad71c50.png)

# %% [markdown]
# ```cpp
#
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
# int f(vector<string>&strings){
#     if(strings.empty())return 0;
#
#
#     string prefix=strings[0];
#
#
#     for(int i=1;i<strings.size();i++){
#         int j=0;
#         while(j<prefix.size() && j<strings[i].size() && prefix[j]==strings[i][j]){
#             j++;
#         }
#
#         prefix=prefix.substr(0,j);
#
#
#         if(prefix.empty())return 0;
#     }
#     return prefix.size();
# }
#
#
# void solve(){
#
#     int n;cin>>n;
#     vector<string>strings;
#     for(int i=0;i<n;i++){
#         string s;
#         cin>>s;
#         strings.push_back(s);
#     }
#
#
#     int result=f(strings);
#     cout<<result<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:8aaf04d3-3ba8-47f4-8713-31e6aa81fd30.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#
#     int n;
#     cin>>n;
#     string s;
#     cin>>s;
#     int head=-1,tail=0;
#
#     int sum=0;
#
#     int ans=0;
#     int startIndex=-1;
#
#
#     unordered_map<int,int>mp;
#
#     mp[0]=-1;
#
#     while(tail<n){
#         while(head+1<n){
#             head++;
#             if(s[head]=='0'){
#                 sum--;
#             }else{
#                 sum++;
#             }
#
#
#             if(mp.find(sum)!=mp.end()){
#                 int len=head-mp[sum];
#                 if(len>ans){
#                     ans=len;
#                     startIndex=mp[sum]+1;
#                 }
#
#             }else{
#                 mp[sum]=head;
#             }
#         }
#
#         if(tail>head){
#             tail++;
#             head=tail-1;
#         }else{
#
#             if(s[tail]=='0'){
#                 sum++;
#             }else{
#                 sum--;
#             }
#
#             tail++;
#
#         }
#     }
#
#
#
#
#
#     cout<<s.substr(startIndex,ans)<<endl;
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:e4a8812b-a6b7-4e66-81fb-ff45ad052f26.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#
#     int n;
#     cin>>n;
#     int j=0;
#     vector<int>arr(n);
#     for(int i=0;i<n;i++){
#         cin>>arr[i];
#     }
#     for(int i=0;i<n;i++){
#         if(arr[i]>0){
#             swap(arr[i],arr[j]);
#             j++;
#         }
#     }
#
#     for(int i=0;i<n;i++){
#         cout<<arr[i]<<" ";
#     }
#     cout<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:106425f6-ea3b-47e1-869d-be16b1a6494b.png)

# %% [markdown]
# ```cpp
#
#
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#     int n;
#     cin>>n;
#     int suma=0,sumb=0;
#     vector<int>a(n),b(n);
#     for(int i=0;i<n;i++)cin>>a[i],suma+=a[i];
#     for(int i=0;i<n;i++)cin>>b[i],sumb+=b[i];
#     int ans=max(suma,sumb);
#     int mx=0,mn=0;
#
#     int pa=0,pb=0;
#     for(int i=0;i<n;i++){
#         pa+=a[i];
#         pb+=b[i];
#
#
#         int tempa=suma+pb-pa+mx;
#         int tempb=sumb+pb-pa+mn;
#         ans=max({ans,tempa,tempb});
#         mx=max(mx,pa-pb);
#         mn=min(mn,pa-pb);
#     }
#     cout<<ans<<endl;
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:2c7bec85-4257-42c4-a0c7-37a5c5552d5b.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
#
#     int n;
#     cin>>n;
#     map<string,int>cnt;
#     for(int i=0;i<n;i++){
#         int x;
#         cin>>x;
#         string s=to_string(x);
#         cnt[s]++;
#     }
#
#     string q;
#     cin>>q;
#     int ans=0;
#
#     for(int i=0;i<q.size();i++){
#         string s1=q.substr(0,i+1);
#         string s2=q.substr(i+1);
#
#
#         if(s1==s2){
#             ans+=(cnt[s1]*(cnt[s1]-1)/2);
#         }else{
#             ans+=(cnt[s1]*cnt[s2]);
#         }
#     }
#     cout<<ans<<endl;
#
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:93297e2e-b7c3-415b-963a-7b51aa46196d.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
# using state=pair<int,pair<int,int>>;
#
# void solve(){
#
#
#
#     int n,m,k;
#     cin>>n>>m>>k;
#
#
#     vector<vector<char>>grid(n,vector<char>(m));
#
#     for(int i=0;i<n;i++){
#         for(int j=0;j<m;j++){
#             cin>>grid[i][j];
#         }
#     }
#
#
#     vector<vector<vector<int>>>dist(n,vector<vector<int>>(m,vector<int>(k+1,INT_MAX)));
#
#     queue<state>q;
#     q.push({0,{0,0}});
#
#     dist[0][0][0]=0;
#
#     vector<vector<int>>moves={{1,0},{-1,0},{0,1},{0,-1}};
#
#     while(!q.empty()){
#         auto node=q.front();
#
#
#         q.pop();
#         int obstacle=node.first;
#         int x=node.second.first;
#         int y=node.second.second;
#
#
#
#         for(auto &move:moves){
#             int nx=x+move[0];
#             int ny=y+move[1];
#
#
#
#             if(nx>=0 && ny>=0 && nx<n and ny<m and grid[nx][ny]=='0' and dist[nx][ny][obstacle]==INT_MAX){
#                 dist[nx][ny][obstacle]=dist[x][y][obstacle]+1;
#                 q.push({obstacle,{nx,ny}});
#             }
#
#              if(obstacle==k){
#                 continue;
#             }
#
#             if(nx>=0 && ny>=0 && nx<n and ny<m and grid[nx][ny]=='1' and dist[nx][ny][obstacle+1]==INT_MAX){
#                 dist[nx][ny][obstacle+1]=dist[x][y][obstacle]+1;
#                 q.push({obstacle+1,{nx,ny}});
#             }
#
#
#
#         }
#     }
#
#
#     int ans=INT_MAX;
#
#
#     for(int i=0;i<=k;i++){
#         ans=min(ans,dist[n-1][m-1][i]);
#     }
#
#
#     if(ans==INT_MAX){
#         cout<<-1<<endl;
#     }else{
#         cout<<ans<<endl;
#     }
#
#
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:fbcc180d-174d-4379-85ac-bac361aef0a7.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
# using state=pair<int,pair<int,int>>;
#
# void solve(){
#
#
#     string a,b;
#     cin>>a>>b;
#     map<char,int>mp1;
#     map<char,int>mp2;
#     for(auto &ch:a)mp1[ch]++;
#     for(auto &ch:b)mp2[ch]++;
#     bool flag=true;
#     for(int i=0;i<a.size();i++){
#         if(abs(mp1[a[i]]-mp2[b[i]])>3){
#             flag=false;
#             break;
#         }
#     }
#     for(int i=0;i<b.size();i++){
#         if(abs(mp1[a[i]]-mp2[b[i]])>3){
#             flag=false;
#             break;
#         }
#     }
#
#
#     if(a.size()==0 || b.size()==0){
#         cout<<"NO";
#         return;
#     }
#
#
#     if(flag){
#         cout<<"YES"<<endl;
#     }else{
#         cout<<"NO"<<endl;
#     }
#
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:72aa934f-cf2c-4a1f-a0a7-ee1f9949fcf0.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
# int dp[305][305];
#
#
# int f(vector<int>arr,int i,int j){
#     if(i>j)return 0;
#
#
#     if(dp[i][j]!=-1)return dp[i][j];
#
#
#     int ans=INT_MIN;
#
#
#     for(int k=i;k<=j;k++){
#         ans=max(ans,f(arr,i,k-1)+f(arr,k+1,j)+arr[i-1]*arr[k]*arr[j+1]);
#     }
#     return dp[i][j]=ans;
# }
#
#
#
# void solve(){
#
#
#     int n;
#     cin>>n;
#     vector<int>nums(n);
#     for(int i=0;i<n;i++)cin>>nums[i];
#
#
#     nums.push_back(1);
#     nums.insert(nums.begin(),1);
#     memset(dp,-1,sizeof(dp));
#     cout<<f(nums,1,n);
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }
