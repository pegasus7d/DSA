# %% [markdown]
# ![image.png](attachment:5fb4c90c-6550-4b10-9537-5e84de644926.png)

# %% [markdown]
# ```cpp
#
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
#
#
#
# /*
# #include <ext/pb_ds/assoc_container.hpp>
# #include <ext/pb_ds/tree_policy.hpp>
# using namespace __gnu_pbds;
#
# typedef tree<int, null_type, less_equal<int>, rb_tree_tag, tree_order_statistics_node_update> ordered_set;
#
# */
#
# #define int long long
# /*
#
# os.find_by_order(os.order_of_key(num));
# os.order_of_key(num) position of number
# */
#
# void solve(){
#
# 	int n;
# 	cin>>n;
#
#
# 	vector<int>arr(n);
# 	for(int i=0;i<n;i++){
# 		cin>>arr[i];
# 	}
# 	int ans=n*(n+1)/2;
#
#
# 	int cnt=0;
# 	vector<int>m(2*n);
# 	map<int,int>mp;
# 	m[0]=1;
# 	int cur=0;
#
# 	//number of subarrays whose xor is  perfect square
# 	// 4......4.... 4.....4
# 	for(int i=0;i<n;i++){
# 		cur=cur^arr[i];
# 		for(int j=0;j*j<2*n;j++){
# 			if((cur^(j*j))<(2*n)){
#
# 				//
# 				cnt+=m[cur^(j*j)];
# 			}
# 		}
# 		m[cur]++;
# 	}
#
# 	cout<<ans-cnt<<endl;
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# https://codeforces.com/contest/1731/problem/C

# %% [markdown]
# ![image.png](attachment:96522936-6818-4bc1-b5bf-c567a1505080.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
#
#
#
# /*
# #include <ext/pb_ds/assoc_container.hpp>
# #include <ext/pb_ds/tree_policy.hpp>
# using namespace __gnu_pbds;
#
# typedef tree<int, null_type, less_equal<int>, rb_tree_tag, tree_order_statistics_node_update> ordered_set;
#
# */
#
# #define int long long
# /*
#
# os.find_by_order(os.order_of_key(num));
# os.order_of_key(num) position of number
# */
#
# void solve(){
#
#
# 	int n;
# 	cin>>n;
# 	map<int,vector<int>>mp;
# 	vector<int>arr(n);
# 	for(int i=0;i<n;i++){
# 		cin>>arr[i];
# 		mp[arr[i]/4].push_back(arr[i]);
# 	}
# 	for(auto &it:mp){
# 		sort(it.second.begin(),it.second.end());
# 	}
#
# 	vector<int>ans(n);
# 	for(int i=n-1;i>=0;i--){
# 		int x=arr[i]/4;
# 		ans[i]=mp[x].back();
# 		mp[x].pop_back();
# 	}
#
# 	for(int i=0;i<n;i++){
# 		cout<<ans[i]<<" ";
# 	}
# 	cout<<endl;
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# https://codeforces.com/problemset/problem/1971/G
