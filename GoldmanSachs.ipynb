# %% [markdown]
# ![image.png](attachment:4512bde7-654b-4a11-ac50-2fa7e50625af.png)

# %% [markdown]
# ```cpp
# class Solution {
# public:
#     bool reachingPoints(int sx, int sy, int tx, int ty) {
#
#
#         while(tx>=sx && ty>=sy){
#
#
#             if(tx>ty){
#                 if(sy==ty){
#                     if((tx-sx)%ty==0){
#                         return true;
#                     }else{
#                         return false;
#                     }
#                 }
#                 tx%=ty;
#
#             }else{
#
#                 if(sx==tx){
#                     if((ty-sy)%tx==0){
#                         return true;
#                     }else{
#                         return false;
#                     }
#                 }
#
#
#
#                 ty%=tx;
#
#             }
#         }
#
#         return false;
#
#     }
# };

# %% [markdown]
# ![image.png](attachment:ad4db9e6-4233-40a8-9c57-7e4198ad28e9.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
#
#
#
# /*
# #include <ext/pb_ds/assoc_container.hpp>
# #include <ext/pb_ds/tree_policy.hpp>
# using namespace __gnu_pbds;
#
# typedef tree<int, null_type, less_equal<int>, rb_tree_tag, tree_order_statistics_node_update> ordered_set;
#
# */
#
# #define int long long
# /*
#
# os.find_by_order(os.order_of_key(num));
# os.order_of_key(num) position of number
# */
#
# void solve(){
#
#     string s;
#     cin>>s;
#     string ans="";
#     for(auto &ch:s){
#         ans+=to_string((int)ch);
#     }
#     cout<<ans<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:3d357605-7886-44b3-bae0-6cb96af94c0b.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
#
#
#
# /*
# #include <ext/pb_ds/assoc_container.hpp>
# #include <ext/pb_ds/tree_policy.hpp>
# using namespace __gnu_pbds;
#
# typedef tree<int, null_type, less_equal<int>, rb_tree_tag, tree_order_statistics_node_update> ordered_set;
#
# */
#
# #define int long long
# /*
#
# os.find_by_order(os.order_of_key(num));
# os.order_of_key(num) position of number
# */
#
#
# double area(pair<int,int>&p1,pair<int,int>&p2,pair<int,int>&p3){
#     int x1=p1.first;
#     int x2=p2.first;
#     int x3=p3.first;
#     int y1=p1.second;
#     int y2=p2.second;
#     int y3=p3.second;
#
#
#     return (abs(x1*(y2-y3)+x2*(y3-y1)+x3*(y1-y2)))/2.0;
# }
#
# void solve(){
#
#     pair<int,int>a,b,c,p,q;
#     cin>>a.first>>a.second>>b.first>>b.second>>c.first>>c.second>>p.first>>p.second>>q.first>>q.second;
#
#     double total=area(a,b,c);
#
#     if(total==0){
#         cout<<0<<endl;
#     }else{
#
#         double p1=area(a,b,p);
#         double p2=area(b,c,p);
#         double p3=area(c,a,p);
#
#
#         bool pp=(total==(p1+p2+p3));
#
#         double q1=area(a,b,q);
#         double q2=area(b,c,q);
#         double q3=area(c,a,q);
#
#
#         bool qq=(total==(q1+q2+q3));
#
#
#         if(pp && qq){
#             cout<<3<<endl;
#         }else if(pp){
#             cout<<1<<endl;
#         }else if(qq){
#             cout<<2<<endl;
#         }else{
#             cout<<4<<endl;
#         }
#
#
#
#
#
#     }
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:70c249be-6237-4339-887b-951f8bdd879e.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
#
#
#
# /*
# #include <ext/pb_ds/assoc_container.hpp>
# #include <ext/pb_ds/tree_policy.hpp>
# using namespace __gnu_pbds;
#
# typedef tree<int, null_type, less_equal<int>, rb_tree_tag, tree_order_statistics_node_update> ordered_set;
#
# */
#
# #define int long long
# /*
#
# os.find_by_order(os.order_of_key(num));
# os.order_of_key(num) position of number
# */
#
# void solve(){
#
#     int n;
#     cin>>n;
#     vector<int>arr(n);
#
#     int es=0,os=0,x=0,y=0;
#     for(int i=0;i<n;i++){
#         cin>>arr[i];
#     }
#
#     for(int i=0;i<n;i++){
#         if(i%2==0){
#             if(x%2==0){
#                 es+=arr[i];
#             }else{
#                 es*=arr[i];
#             }
#             x++;
#         }else{
#             if(y%2==0){
#                 os+=arr[i];
#             }else{
#                 os*=arr[i];
#             }
#             y++;
#         }
#     }
#
#
#     os=abs(os%2);
#     es=abs(es%2);
#
#     if(es>os){
#         cout<<"EVEN"<<endl;
#     }else if(es<os){
#         cout<<"ODD"<<endl;
#     }else{
#         cout<<"NEUTRAL"<<endl;
#     }
#
#
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:85ce2c06-1d0f-43c0-9acc-8385823627e5.png)

# %% [markdown]
# ```cpp
# class Solution {
# public:
#     int countSubstrings(string s) {
#
#         string t="#";
#         for(auto ch:s){
#             t.push_back(ch);
#             t.push_back('#');
#         }
#
#         int center=0,rightBoundary=0;
#         vector<int>p(t.size());
#         int ans=0;
#         for(int i=0;i<t.size();i++){
#
#             int mirror=2*center-i;
#             if(i<rightBoundary)
#                 p[i]=min(rightBoundary-i,p[mirror]);
#
#             int right=i+p[i]+1;
#             int left=i-p[i]-1;
#
#             while(left>=0 && right<t.size() && t[left]==t[right]){
#                 p[i]++;
#                 right++;
#                 left--;
#             }
#
#
#             if(i+p[i]>rightBoundary){
#                 center=i;
#                 rightBoundary=i+p[i];
#             }
#
#             ans+=(p[i]+1)/2;
#
#
#
#
#         }
#         return ans;
#
#     }
# };

# %% [markdown]
# ![image.png](attachment:da717c43-8145-4731-b449-80fd7d4c1389.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
#
#
#
# /*
# #include <ext/pb_ds/assoc_container.hpp>
# #include <ext/pb_ds/tree_policy.hpp>
# using namespace __gnu_pbds;
#
# typedef tree<int, null_type, less_equal<int>, rb_tree_tag, tree_order_statistics_node_update> ordered_set;
#
# */
#
# #define int long long
# /*
#
# os.find_by_order(os.order_of_key(num));
# os.order_of_key(num) position of number
# */
#
# void solve(){
#
#     string s;
#     cin>>s;
#     int i=0;
#     int n=s.size();
#     map<char,int>mp;
#     while(i<n){
#         char ch=s[i];
#         int j=i+1;
#         int x=0;
#
#         while(j<n && isdigit(s[j])){
#             x=x*10+(s[j]-'0');
#             j++;
#         }
#         mp[ch]+=x;
#         i=j;
#     }
#     string ans="";
#     for(auto it:mp){
#         ans+=it.first;
#         ans+=to_string(it.second);
#     }
#
#     cout<<ans<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:847bfb3b-7a5f-454f-a317-a4024f8f5aa9.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
#
#
#
# /*
# #include <ext/pb_ds/assoc_container.hpp>
# #include <ext/pb_ds/tree_policy.hpp>
# using namespace __gnu_pbds;
#
# typedef tree<int, null_type, less_equal<int>, rb_tree_tag, tree_order_statistics_node_update> ordered_set;
#
# */
#
# #define int long long
# /*
#
# os.find_by_order(os.order_of_key(num));
# os.order_of_key(num) position of number
# */
#
# void solve(){
#
#     int n,k;
#     cin>>n>>k;
#     vector<int>arr(n);
#     for(int i=0;i<n;i++){
#         cin>>arr[i];
#     }
#
#     int head=-1,tail=0;
#     int sum=0;
#     int ans=0;
#
#     while(tail<n){
#         while(head+1<n && sum+arr[head+1]<k){
#             head++;
#             sum+=arr[head];
#
#         }
#         ans=max(ans,head-tail+1);
#
#         if(tail>head){
#             tail++;
#             head=tail-1;
#         }else{
#             sum-=arr[tail];
#             tail++;
#         }
#
#
#
#     }
#
#     cout<<ans<<endl;
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }
