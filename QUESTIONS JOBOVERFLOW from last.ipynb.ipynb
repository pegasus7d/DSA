# %% [markdown]
# ![image.png](attachment:fd24dc3c-a34d-401f-abdd-41b9bcb89b6c.png)

# %% [markdown]
# ```cpp
#
# code to be found

# %% [markdown]
# ![image.png](attachment:6cbba7d1-823f-4780-a599-4be96199b19f.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
# 	int n,N;
# 	cin>>n>>N;
#
#
# 	unordered_set<int>st;
# 	int vis=0;
#
# 	for(int i=0;i<n;i++){
# 		int x;
# 		cin>>x;
# 		if(st.find(x)!=st.end()){
# 			continue;
# 		}
#
# 		for(int j=x;j<=N;j+=x){
# 			if(st.find(x)==st.end()){
# 				vis++;
# 				st.insert(j);
# 			}
# 		}
# 	}
#
# 	cout<<vis<<endl;
#
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:8524ef30-4d7f-4cbc-81ac-a96315434676.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
#
#
#
# void solve(){
#
# 	int n;
# 	cin>>n;
# 	vector<int>arr(n);
# 	int total_sum=0;
# 	int smallest_odd=1001;
# 	for(int i=0;i<n;i++){
# 		cin>>arr[i];
# 		total_sum+=arr[i];
#
# 		if(arr[i]&1){
# 			smallest_odd=min(smallest_odd,arr[i]);
#
# 		}
# 	}
#
#
#     if(total_sum&1){
#
#     	if(smallest_odd==1001){
#     		cout<<"0"<<endl;
#     	}else{
#     		cout<<total_sum-smallest_odd;
#
#     	}
#
#     }else{
#     	cout<<total_sum<<endl;
#     }
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:121dea02-d3f7-44d6-bfdd-88215339730e.png)

# %% [markdown]
# ```cpp
# #include <bits/stdc++.h>
# using namespace std;
# #define endl '\n'
# #define int long long
#
# bool check(vector<int>&pieces,int k,int minShare){
# 	int count=0;
# 	int curWt=0;
# 	for(auto wt:pieces){
# 		curWt+=wt;
# 		if(curWt>=minShare){
# 			count++;
# 			curWt=0;
# 		}
# 	}
# 	return count>=k;
# }
#
#
#
#
#
# void solve(){
#     int n,k;
#     cin>>n>>k;
#
#     vector<int>pieces(n);
#     for(int i=0;i<n;i++){
#     	cin>>pieces[i];
#     }
#
#     int l=1;
#     int r=accumulate(pieces.begin(),pieces.end(),0);
#     int ans=0;
#     while(l<=r){
#     	int mid=l+(r-l)/2;
#
#     	if(check(pieces,k,mid)){
#     		ans=mid;
#     		l=mid+1;
#
#     	}else{
#     		r=mid-1;
#     	}
#     }
#     cout<<ans<<endl;
#
#
#
# }
#
# signed main(){
#     ios_base::sync_with_stdio(false);
#     cin.tie(NULL);cout.tie(NULL);
#     // int _t;cin>>_t;while(_t--)
#     solve();
# }

# %% [markdown]
# ![image.png](attachment:d93ec6f7-8fb7-4a38-a3d7-a7d81a26a797.png)
# ![image.png](attachment:ed3f9da3-300f-4887-b898-685e5c0cd42c.png)

# %% [markdown]
# ```cpp
#
# code to be found

# %% [markdown]
# ![image.png](attachment:b23127ea-3618-4da1-bf9b-10606733883b.png)

# %% [markdown]
# ```cpp
#
# code to be found

# %% [markdown]
# ![image.png](attachment:946424fd-12d0-43a2-88ff-0b3de6b301a9.png)

# %% [markdown]
# ```cpp
#
# code to be found
